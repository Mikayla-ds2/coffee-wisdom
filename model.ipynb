# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv('Coffe_sales.csv')

# %%
df = df.drop(columns=['Weekdaysort', 'Monthsort'])

# %%
df.head()
# Out:
#    hour_of_day cash_type  money    coffee_name Time_of_Day Weekday Month_name  \
# 0           10      card   38.7          Latte     Morning     Fri        Mar
# 1           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 2           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 3           13      card   28.9      Americano   Afternoon     Fri        Mar
# 4           13      card   38.7          Latte   Afternoon     Fri        Mar
#
#          Date             Time
# 0  2024-03-01  10:15:50.520000
# 1  2024-03-01  12:19:22.539000
# 2  2024-03-01  12:20:18.089000
# 3  2024-03-01  13:46:33.006000
# 4  2024-03-01  13:48:14.626000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3547 entries, 0 to 3546
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hour_of_day  3547 non-null   int64
#  1   cash_type    3547 non-null   object
#  2   money        3547 non-null   float64
#  3   coffee_name  3547 non-null   object
#  4   Time_of_Day  3547 non-null   object
#  5   Weekday      3547 non-null   object
#  6   Month_name   3547 non-null   object
#  7   Date         3547 non-null   object
#  8   Time         3547 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 249.5+ KB

# %%
df = df.drop(columns='cash_type')

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum() / len(df) * 100
# Out:
# hour_of_day    0.0
# money          0.0
# coffee_name    0.0
# Time_of_Day    0.0
# Weekday        0.0
# Month_name     0.0
# Date           0.0
# Time           0.0
# dtype: float64

# %%
df.describe()
# Out:
#        hour_of_day        money
# count  3547.000000  3547.000000
# mean     14.185791    31.645216
# std       4.234010     4.877754
# min       6.000000    18.120000
# 25%      10.000000    27.920000
# 50%      14.000000    32.820000
# 75%      18.000000    35.760000
# max      22.000000    38.700000

# %%
import sys
# !{sys.executable} -m pip install ydata-profiling
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from ydata_profiling import ProfileReport
# Out:
# /var/folders/xg/9_zxrtsn0ll10hckyb7z5l780000gn/T/ipykernel_27315/44057814.py:1: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install data-profiling via `pip install data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df, title='Coffee Wisdom', explorative=True)

profile.to_file("analysis_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
